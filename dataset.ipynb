# %% [markdown]
# <a href="https://colab.research.google.com/github/rudraksh97/CoronaNet/blob/master/dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# %%
#Used to setup Google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#Getting the entire repository so as to get it updated everytime you use this code. The repository is updated regularly by the owner.
# !git clone https://github.com/ieee8023/covid-chestxray-dataset.git
# Out:
# Cloning into 'covid-chestxray-dataset'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 1230 (delta 0), reused 0 (delta 0), pack-reused 1227
# Receiving objects: 100% (1230/1230), 199.08 MiB | 37.88 MiB/s, done.
# Resolving deltas: 100% (570/570), done.
# Checking out files: 100% (296/296), done.

# %%
#This code was used to download dataset in my google drive

#os.environ['KAGGLE_CONFIG_DIR'] = "/content/drive/My Drive/Kaggle"
#cd /content/drive/My Drive/Kaggle
#!kaggle datasets download -d paultimothymooney/chest-xray-pneumonia
#!unzip \*.zip  && rm *.zip

# %%
# filenames = []
# for root,dirs,files in os.walk("/content/covid-chestxray-dataset/images"):
#   for name in files:
#     print(name)

# %%
dataset1 = "/content/covid-chestxray-dataset"
dataset2 = "/content/drive/My Drive/Kaggle/chest_xray/train/NORMAL"

# %%
filenames = {'normal': [], 'pneumonia': [], 'COVID-19': []}

# %%
for root,dirs,files in os.walk(dataset2):
  for name in files:
    filenames['normal'].append(dataset2 + "/" + name)

# %%
csvfile = pd.read_csv(dataset1 + "/metadata.csv")
csvfile = csvfile[csvfile["view"] == "PA"]

# %%
from collections import Counter
Counter(list(csvfile.finding))
# Out:
# Counter({'ARDS': 4,
#          'COVID-19': 108,
#          'COVID-19, ARDS': 10,
#          'Chlamydophila': 1,
#          'Klebsiella': 1,
#          'Legionella': 2,
#          'No Finding': 1,
#          'Pneumocystis': 13,
#          'SARS': 16,
#          'Streptococcus': 13})

# %%
for ind in csvfile.index:
  temp = csvfile['finding'][ind]
  fname = csvfile['filename'][ind]
  if("COVID-19" in temp):
    filenames["COVID-19"].append("/content/covid-chestxray-dataset/images/" + fname)
  else:
    filenames["pneumonia"].append("/content/covid-chestxray-dataset/images/" + fname)

# %%
filenames
# Out:
# {'COVID-19': ['/content/covid-chestxray-dataset/images/auntminnie-a-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg',
#   '/content/covid-chestxray-dataset/images/auntminnie-b-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg',
#   '/content/covid-chestxray-dataset/images/auntminnie-c-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg',
#   '/content/covid-chestxray-dataset/images/auntminnie-d-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg',
#   '/content/covid-chestxray-dataset/images/nejmc2001573_f1a.jpeg',
#   '/content/covid-chestxray-dataset/images/nejmc2001573_f1b.jpeg',
#   '/content/covid-chestxray-dataset/images/lancet-case2a.jpg',
#   '/content/covid-chestxray-dataset/images/lancet-case2b.jpg',
#   '/content/covid-chestxray-dataset/images/1-s2.0-S0140673620303706-fx1_lrg.jpg',
#   '/content/covid-chestxray-dataset/images/nCoV-radiol.2020200269.fig1-day7.jpeg',
#   '/content/covid-chestxray-dataset/images/nejmoa2001191_f1-PA.jpeg',
# ...

# %%
f1= open("normal.txt","w+")
f1.writelines( "%s\n" % item for item in filenames['normal'])
f1.close()

# %%
f2 = open("covid.txt","w+")
f2.writelines( "%s\n" % item for item in filenames['COVID-19'])
f2.close()

# %%
f3 = open("pneumonia.txt","w+")
f3.writelines("%s\n" % item for item in filenames['pneumonia'])
f3.close()
